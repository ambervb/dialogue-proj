# %%
#Importing all needed librarys
import torch
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
from torchvision.transforms import ToTensor, Lambda, Compose
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
from pipetorch.train import *
from torch.autograd import Variable
from torch.nn import Linear, ReLU, CrossEntropyLoss, Sequential, Conv2d, MaxPool2d, Module, Softmax, BatchNorm2d, Dropout
from torch.optim import Adam, SGD
from tqdm import tqdm
from torch import nn, optim
import seaborn as sns
import torch.nn.functional as F

# importing the libraries
import pandas as pd
import numpy as np

# for creating validation set
from sklearn.model_selection import train_test_split


import torchvision
from torchvision.datasets import ImageFolder
# Out:
# using gpu 3

# %%
#Checking wich GPU is beeing used

# !nvidia-smi
# Out:
# Fri Dec 17 14:50:36 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.86       Driver Version: 470.86       CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ...  Off  | 00000000:05:00.0 Off |                  N/A |
# | 32%   47C    P8    19W / 250W |   5590MiB / 11019MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  NVIDIA GeForce ...  Off  | 00000000:09:00.0 Off |                  N/A |
# | 29%   27C    P8    20W / 250W |   8688MiB / 11019MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   2  NVIDIA GeForce ...  Off  | 00000000:0A:00.0 Off |                  N/A |
# | 30%   26C    P8     3W / 250W |   7531MiB / 11019MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   3  NVIDIA GeForce ...  Off  | 00000000:85:00.0 Off |                  N/A |
# | 32%   44C    P2    54W / 250W |   4627MiB / 11019MiB |     10%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   4  NVIDIA GeForce ...  Off  | 00000000:89:00.0 Off |                  N/A |
# | 29%   24C    P8     1W / 250W |   7329MiB / 11019MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      2603      C   ...erhub/anaconda/bin/python     2747MiB |
# |    0   N/A  N/A     13252      C   ...erhub/anaconda/bin/python     1735MiB |
# |    0   N/A  N/A     31850      C   ...erhub/anaconda/bin/python     1105MiB |
# |    1   N/A  N/A      2441      C   ...erhub/anaconda/bin/python     5111MiB |
# |    1   N/A  N/A      6055      C   ...erhub/anaconda/bin/python     2501MiB |
# |    1   N/A  N/A     25669      C   ...erhub/anaconda/bin/python     1073MiB |
# |    2   N/A  N/A      5796      C   ...erhub/anaconda/bin/python     2669MiB |
# |    2   N/A  N/A     21380      C   ...erhub/anaconda/bin/python     4859MiB |
# |    3   N/A  N/A      7431      C   ...erhub/anaconda/bin/python     1329MiB |
# |    3   N/A  N/A     16765      C   ...erhub/anaconda/bin/python     1079MiB |
# |    3   N/A  N/A     23719      C   python3                          1135MiB |
# |    3   N/A  N/A     46951      C   ...erhub/anaconda/bin/python     1081MiB |
# |    4   N/A  N/A      9021      C   ...erhub/anaconda/bin/python     3137MiB |
# |    4   N/A  N/A     13453      C   ...erhub/anaconda/bin/python      981MiB |
# |    4   N/A  N/A     17870      C   ...erhub/anaconda/bin/python     1059MiB |
# |    4   N/A  N/A     22139      C   ...erhub/anaconda/bin/python     2149MiB |
# +-----------------------------------------------------------------------------+

# %%
#Load data
data_file_true = 'dialogue/Dataset/VoiceDetection/Big_dataset/Output_true.npy'
data_file_false = 'dialogue/Dataset/VoiceDetection/Big_dataset/Output_false.npy'

true_data = np.load(data_file_true, allow_pickle = True)
false_data = np.load(data_file_false, allow_pickle = True)
df_true_data = pd.DataFrame(true_data)
df_false_data = pd.DataFrame(false_data)

df_true_data['label'] = True
df_false_data['label'] = False
#print(data)

#df_data['data'] = df_temp.values.tolist()
df_data = pd.concat([df_true_data, df_false_data])
#print(df_data.head())
np_labels = df_data['label'].to_numpy()
np_data = df_data.drop(['label'],axis = 1).to_numpy()
print(df_data)
print(np_labels)
# Out:
#                 0           1           2           3           4           5  \
# 0     -602.022766 -602.723755 -603.376587 -604.697205 -604.944519 -604.832581
# 1     -184.963791 -167.952698 -158.673050 -179.185837 -206.072037 -246.351532
# 2     -273.273712 -253.240891 -222.000061 -167.081268 -170.382721 -216.621155
# 3     -612.132263 -605.841003 -601.784912 -606.503540 -611.724365 -615.397827
# 4      -99.539803 -116.719917 -150.092438 -132.454346 -153.093674 -134.829453
# ...           ...         ...         ...         ...         ...         ...
# 19995  -98.696381 -146.676620 -321.676208 -422.174591 -432.748322 -428.995758
# 19996 -432.957977 -425.469818 -424.276611 -431.652863 -432.145569 -430.457733
# 19997 -196.815552 -247.848114 -390.696655 -428.601593 -427.747406 -428.584503
# 19998 -434.154480 -429.234955 -431.356506 -430.332977 -432.144257 -431.375946
# 19999 -151.141281 -196.110397 -353.022400 -425.890198 -426.080780 -427.372894
#
#                 6           7           8           9  ...       631  \
# 0     -603.640930 -603.905579 -603.193604 -602.144897  ... -1.490322
# 1     -192.083542 -146.408859 -157.208023 -198.767258  ... -3.480276
# 2     -277.315552 -320.871552 -334.336792 -351.263824  ...  5.243487
# 3     -625.228577 -631.997192 -626.594727 -625.460022  ... -3.036524
# 4     -143.458618 -170.721451 -204.473801 -193.664001  ... -2.378895
# ...           ...         ...         ...         ...  ...       ...
# 19995 -426.697510 -425.693390 -427.651184 -433.953369  ... -0.814556
# 19996 -426.739594 -424.033112 -426.662628 -426.487244  ... -6.220835
# 19997 -428.296906 -424.919983 -425.206421 -430.088837  ... -1.475617
# 19998 -428.022888 -429.424255 -430.100769 -430.447876  ... -4.782631
# 19999 -431.044159 -427.759460 -426.938934 -423.598907  ... -4.187718
#
#             632       633       634        635        636       637  \
# 0     -0.442998 -0.800406 -0.276425   1.223736   1.203523 -2.704047
# 1     -3.430368 -2.594002 -6.455566  -8.532133  -4.658223 -5.588761
# 2     -1.946541 -3.936874 -3.429468  -5.729334   1.509373  0.938021
# 3     -1.338205 -5.128219 -9.585898  -7.765177  -4.942265  4.092947
# 4     -7.086716 -1.524186  3.279835  11.558123  16.236721  5.887723
# ...         ...       ...       ...        ...        ...       ...
# 19995 -1.236556 -1.909662 -2.717530  -0.368847  -0.751032 -8.299664
# 19996 -5.822928 -4.315157  0.093720   3.234744   0.689510 -0.757822
# 19997 -0.020784 -3.588493 -1.763600  -1.229148  -3.562918 -6.539064
# 19998 -1.552987 -0.168691 -3.639297   0.288705   5.127940 -0.936800
# 19999 -4.464233 -3.909778 -1.276556   0.350008   1.319580 -2.419193
#
#              638       639  label
# 0      -7.933941 -2.587589   True
# 1      -1.227415  1.011745   True
# 2      -2.572014 -3.787780   True
# 3       3.868603  7.752074   True
# 4       4.577003  1.655415   True
# ...          ...       ...    ...
# 19995 -10.491957 -9.135324  False
# 19996   1.299556 -3.880665  False
# 19997  -2.745670 -3.142720  False
# 19998  -4.059626 -2.631584  False
# 19999  -0.266939  2.655121  False
#
# [26373 rows x 641 columns]
# [ True  True  True ... False False False]

# %%
data_file = 'dialogue/Dataset/VoiceDetection/Output.npy'
labels = pd.read_csv("dialogue/Dataset/VoiceDetection/boolean_labels.csv")#path to csv
labels.drop(labels.columns[[0]], axis=1, inplace=True)
data = np.load(data_file, allow_pickle= True)
df_temp_val = pd.DataFrame()
df_data_val = pd.DataFrame()
#print(data)
df_data_val = pd.DataFrame(data)
#df_data['data'] = df_temp.values.tolist()
df_data_val = pd.concat([df_data_val, labels], axis = 1)
print(df_data_val.head())
np_labels_val = df_data_val['isSpeaking'].to_numpy()
np_data_val = data #df_data['data'].to_numpy()
X_val = np_data_val
y_val = np_labels_val
# Out:
#            0          1          2          3          4          5  \
# 0 -79.563087 -68.802368 -65.000870 -62.749462 -65.189278 -65.297447
# 1 -30.242247 -21.201050 -19.721951 -23.630651 -22.098383 -20.409395
# 2  12.080282  15.370809  19.141037  15.752119  13.640997  16.388205
# 3  41.253902  36.719452  36.724682  31.365046  31.131603  34.598335
# 4 -52.427361 -42.306267 -33.726643 -36.919853 -40.788059 -44.186234
#
#            6          7          8          9  ...      1751      1752  \
# 0 -56.765766 -58.017109 -64.540497 -66.502037  ...  1.097317  4.271942
# 1 -18.435774 -10.034645 -10.490523  -5.373452  ...  3.396949  3.398595
# 2  16.603846  18.023119  14.898715  14.997562  ...  2.044708 -3.925010
# 3  33.079891  35.935799  32.816952  30.094349  ...  5.009474  1.981130
# 4 -46.429951 -37.611927 -39.742786 -51.548973  ...  8.347971  5.515277
#
#        1753      1754      1755      1756      1757      1758      1759  \
# 0  2.806924 -1.344023  2.818498  1.452607  0.640017  1.333346  1.101685
# 1  3.122800  4.543801  8.577129  7.572659  4.918322  4.543025  0.316751
# 2 -8.663915 -9.947154 -3.458650 -2.097382 -0.450698 -0.330577 -2.086427
# 3  4.126915  6.546173  9.440491  9.515235  8.654068  6.661644 -0.681928
# 4 -0.401212  3.110747  3.944249  5.395558  5.490010  4.362657  8.519081
#
#    isSpeaking
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#
# [5 rows x 1761 columns]

# %%
#df_data.drop(['isSpeaking'],axis = 1)
X_train, X_test, y_train, y_test = train_test_split(np_data, np_labels, test_size = 0.2, random_state = 69)
#X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size = 0.2, random_state = 23)

print(type(X_train))
#print(X_train)
# Out:
# <class 'numpy.ndarray'>

# %%
#print(pd.DataFrame(X_train))
X_train = torch.from_numpy(X_train).float()
X_train = X_train.unsqueeze_(-1)
X_train = X_train.transpose(2, 0)
y_train = torch.from_numpy(y_train).float()
X_test = torch.from_numpy(X_test).float()
X_test = X_test.unsqueeze_(-1)
X_test = X_test.transpose(2, 0)        #torch.tensor(X_test.values)
y_test = torch.from_numpy(y_test).float()
X_val = torch.from_numpy(X_val).float()
X_val = X_val.unsqueeze_(-1)
X_val = X_val.transpose(2, 0)
y_val = torch.from_numpy(y_val).float()
#print(X_val.shape, X_val)
print(X_train.shape, y_train.shape)
#print(test_X.shape)
#print(X_train)
# Out:
# torch.Size([1, 640, 21098]) torch.Size([21098])

# %%
class model(nn.Module):
    def __init__(self,n_features,kernel_size):
        super(model, self).__init__()
        self.conv1 = nn.Conv1d(n_features, 1280, kernel_size=1, stride = 1) #1 input channels, 100 output channels
        self.conv2 = nn.Conv1d(1280, 320, kernel_size=1, stride = 1) #100 input channels from previous Conv. layer, 75 out
        self.conv3 = nn.Conv1d(320, 160, kernel_size=1, stride = 1) #75 input channels from previous Conv. layer, 50 out
        self.conv4 = nn.Conv1d(160, 80, kernel_size=1, stride = 1) #75 input channels from previous Conv. layer, 50 out
        # self.conv5 = nn.Conv1d(80, 60, kernel_size=1, stride = 1) #75 input channels from previous Conv. layer, 50 out
        # self.conv5_drop = nn.Dropout2d() #dropout
        
        self.fc1 = nn.Linear(80, 50) #Fully-connected classifier layer
        self.fc2 = nn.Linear(50, 40) #Fully-connected classifier layer
        self.fc3 = nn.Linear(40, 30) #Fully-connected classifier layer
        self.fc4 = nn.Linear(30, 20) #Fully-connected classifier layer
        self.fc5 = nn.Linear(20,1) #Fully-connected classifier layer
    
    def forward(self, x):
        x = F.relu(F.max_pool1d(self.conv1(x), 1))
        x = F.relu(F.max_pool1d(self.conv2(x), 1))
        x = F.relu(F.max_pool1d(self.conv3(x), 1))
        x = F.relu(F.max_pool1d(self.conv4(x), 1))
        # x = F.relu(F.max_pool1d(self.conv5_drop(self.conv5(x)), 1))
        
        #point A
        x = x.transpose(1, 2)
        
        #point B
        x = self.fc1(x)
        x = F.relu(x)
        x = F.dropout(x, training=self.training)
        x = self.fc2(x)
        x = F.relu(x)
        x = self.fc3(x)
        x = F.relu(x)
        x = F.dropout(x, training=self.training)
        x = self.fc4(x)
        return torch.sigmoid(self.fc5(x))
    
    def post_forward(self, y): 
        return torch.round(y)
    
CNN = model(X_train.shape[1],kernel_size = 1)

# %%
weight = torch.FloatTensor([1])
criterion = nn.BCELoss()
optimizer = optim.Adam(CNN.parameters(), lr=0.001)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
X_train = X_train.to(device)
y_train = y_train.to(device)
X_test = X_test.to(device)
y_test = y_test.to(device)
X_val = X_val.to(device)
y_val = y_val.to(device)
CNN = CNN.to(device)
criterion = criterion.to(device)

# %%
def calculate_accuracy(y_true, y_pred):
    return (y_true == y_pred).sum().float() / len(y_true)

# %%
def round_tensor(t, decimal_places=3):
    return round(t.item(), decimal_places)

Results = pd.DataFrame(columns = ['Epoch', 'Acc_train', 'Acc_test', 'test_loss', 'train_loss'])
    
for epoch in range(2000):
        y_pred = CNN(X_train)
        y_pred = torch.squeeze(y_pred)
        train_loss = criterion(y_pred, y_train)
        if epoch % 10 == 0:
        
            train_acc = calculate_accuracy(y_train, CNN.post_forward(y_pred))
        
            y_test_pred = CNN(X_test)

            y_test_pred = torch.squeeze(y_test_pred)
        
            test_loss = criterion(y_test_pred, y_test)
        
            test_acc = calculate_accuracy(y_test, CNN.post_forward(y_test_pred))
        
            result = {'Epoch': epoch, 'Acc_train': round_tensor(train_acc), 'Acc_test': round_tensor(test_acc), 'test_loss': round_tensor(test_loss), 'train_loss': round_tensor(train_loss)}

            Results = Results.append(result, ignore_index=True)

            print(
f'''epoch {epoch}
Train set - loss: {round_tensor(train_loss)}, accuracy: {round_tensor(train_acc)}
Test  set - loss: {round_tensor(test_loss)}, accuracy: {round_tensor(test_acc)}
''')
        optimizer.zero_grad()
    
        train_loss.backward()
    
        optimizer.step()
# Out:
# epoch 0
# Train set - loss: 0.716, accuracy: 0.278
# Test  set - loss: 0.716, accuracy: 0.28
#
# epoch 10
# Train set - loss: 0.372, accuracy: 0.785
# Test  set - loss: 0.36, accuracy: 0.791
#
# epoch 20
# Train set - loss: 0.274, accuracy: 0.906
# Test  set - loss: 0.268, accuracy: 0.906
#
# epoch 30
# Train set - loss: 0.223, accuracy: 0.938
# Test  set - loss: 0.235, accuracy: 0.93
#
# epoch 40
# Train set - loss: 0.148, accuracy: 0.956
# Test  set - loss: 0.187, accuracy: 0.949
#
# epoch 50
# Train set - loss: 0.084, accuracy: 0.972
# Test  set - loss: 0.132, accuracy: 0.96
#
# epoch 60
# Train set - loss: 0.043, accuracy: 0.988
# Test  set - loss: 0.141, accuracy: 0.969
#
# epoch 70
# Train set - loss: 0.027, accuracy: 0.994
# Test  set - loss: 0.149, accuracy: 0.971
#
# epoch 80
# Train set - loss: 0.01, accuracy: 0.999
# Test  set - loss: 0.127, accuracy: 0.978
#
# epoch 90
# Train set - loss: 0.006, accuracy: 1.0
# Test  set - loss: 0.165, accuracy: 0.977
#
# epoch 100
# Train set - loss: 0.004, accuracy: 1.0
# Test  set - loss: 0.306, accuracy: 0.979
#
# epoch 110
# Train set - loss: 0.003, accuracy: 1.0
# Test  set - loss: 0.358, accuracy: 0.977
#
# epoch 120
# Train set - loss: 0.002, accuracy: 1.0
# Test  set - loss: 0.418, accuracy: 0.979
#
# epoch 130
# Train set - loss: 0.002, accuracy: 1.0
# Test  set - loss: 0.453, accuracy: 0.978
#
# epoch 140
# Train set - loss: 0.003, accuracy: 1.0
# Test  set - loss: 0.469, accuracy: 0.979
#
# epoch 150
# Train set - loss: 0.002, accuracy: 1.0
# Test  set - loss: 0.465, accuracy: 0.978
#
# epoch 160
# Train set - loss: 0.002, accuracy: 1.0
# Test  set - loss: 0.547, accuracy: 0.977
#
# epoch 170
# Train set - loss: 0.002, accuracy: 1.0
# Test  set - loss: 0.559, accuracy: 0.978
#
# epoch 180
# Train set - loss: 0.002, accuracy: 1.0
# Test  set - loss: 0.607, accuracy: 0.977
#
# epoch 190
# Train set - loss: 0.002, accuracy: 1.0
# Test  set - loss: 0.554, accuracy: 0.977
#
# epoch 200
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 0.589, accuracy: 0.977
#
# epoch 210
# Train set - loss: 0.002, accuracy: 1.0
# Test  set - loss: 0.7, accuracy: 0.978
#
# epoch 220
# Train set - loss: 0.002, accuracy: 1.0
# Test  set - loss: 0.704, accuracy: 0.977
#
# epoch 230
# Train set - loss: 0.002, accuracy: 1.0
# Test  set - loss: 0.787, accuracy: 0.976
#
# epoch 240
# Train set - loss: 0.002, accuracy: 1.0
# Test  set - loss: 0.691, accuracy: 0.977
#
# epoch 250
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 0.761, accuracy: 0.976
#
# epoch 260
# Train set - loss: 0.002, accuracy: 1.0
# Test  set - loss: 0.708, accuracy: 0.978
#
# epoch 270
# Train set - loss: 0.002, accuracy: 1.0
# Test  set - loss: 0.744, accuracy: 0.977
#
# epoch 280
# Train set - loss: 0.002, accuracy: 1.0
# Test  set - loss: 0.762, accuracy: 0.976
#
# epoch 290
# Train set - loss: 0.002, accuracy: 1.0
# Test  set - loss: 0.806, accuracy: 0.977
#
# epoch 300
# Train set - loss: 0.002, accuracy: 1.0
# Test  set - loss: 0.842, accuracy: 0.977
#
# epoch 310
# Train set - loss: 0.002, accuracy: 1.0
# Test  set - loss: 0.781, accuracy: 0.977
#
# epoch 320
# Train set - loss: 0.002, accuracy: 1.0
# Test  set - loss: 0.754, accuracy: 0.977
#
# epoch 330
# Train set - loss: 0.002, accuracy: 1.0
# Test  set - loss: 0.985, accuracy: 0.976
#
# epoch 340
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 0.947, accuracy: 0.975
#
# epoch 350
# Train set - loss: 0.002, accuracy: 1.0
# Test  set - loss: 0.818, accuracy: 0.979
#
# epoch 360
# Train set - loss: 0.002, accuracy: 1.0
# Test  set - loss: 0.677, accuracy: 0.978
#
# epoch 370
# Train set - loss: 0.002, accuracy: 1.0
# Test  set - loss: 0.734, accuracy: 0.978
#
# epoch 380
# Train set - loss: 42.189, accuracy: 0.532
# Test  set - loss: 43.298, accuracy: 0.521
#
# epoch 390
# Train set - loss: 0.466, accuracy: 0.805
# Test  set - loss: 0.469, accuracy: 0.808
#
# epoch 400
# Train set - loss: 0.229, accuracy: 0.914
# Test  set - loss: 0.235, accuracy: 0.914
#
# epoch 410
# Train set - loss: 0.161, accuracy: 0.942
# Test  set - loss: 0.166, accuracy: 0.94
#
# epoch 420
# Train set - loss: 0.111, accuracy: 0.961
# Test  set - loss: 0.132, accuracy: 0.955
#
# epoch 430
# Train set - loss: 0.074, accuracy: 0.978
# Test  set - loss: 0.109, accuracy: 0.966
#
# epoch 440
# Train set - loss: 0.044, accuracy: 0.989
# Test  set - loss: 0.115, accuracy: 0.971
#
# epoch 450
# Train set - loss: 0.021, accuracy: 0.995
# Test  set - loss: 0.131, accuracy: 0.973
#
# epoch 460
# Train set - loss: 0.009, accuracy: 0.999
# Test  set - loss: 0.195, accuracy: 0.974
#
# epoch 470
# Train set - loss: 0.006, accuracy: 0.999
# Test  set - loss: 0.288, accuracy: 0.975
#
# epoch 480
# Train set - loss: 0.004, accuracy: 1.0
# Test  set - loss: 0.365, accuracy: 0.973
#
# epoch 490
# Train set - loss: 0.003, accuracy: 1.0
# Test  set - loss: 0.411, accuracy: 0.975
#
# epoch 500
# Train set - loss: 0.002, accuracy: 1.0
# Test  set - loss: 0.526, accuracy: 0.974
#
# epoch 510
# Train set - loss: 0.002, accuracy: 1.0
# Test  set - loss: 0.544, accuracy: 0.976
#
# epoch 520
# Train set - loss: 0.002, accuracy: 1.0
# Test  set - loss: 0.56, accuracy: 0.975
#
# epoch 530
# Train set - loss: 0.002, accuracy: 1.0
# Test  set - loss: 0.553, accuracy: 0.975
#
# epoch 540
# Train set - loss: 0.002, accuracy: 1.0
# Test  set - loss: 0.653, accuracy: 0.976
#
# epoch 550
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 0.57, accuracy: 0.975
#
# epoch 560
# Train set - loss: 0.002, accuracy: 1.0
# Test  set - loss: 0.638, accuracy: 0.974
#
# epoch 570
# Train set - loss: 0.002, accuracy: 1.0
# Test  set - loss: 0.747, accuracy: 0.973
#
# epoch 580
# Train set - loss: 0.002, accuracy: 1.0
# Test  set - loss: 0.68, accuracy: 0.975
#
# epoch 590
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 0.695, accuracy: 0.976
#
# epoch 600
# Train set - loss: 0.002, accuracy: 1.0
# Test  set - loss: 0.754, accuracy: 0.976
#
# epoch 610
# Train set - loss: 0.002, accuracy: 1.0
# Test  set - loss: 0.85, accuracy: 0.975
#
# epoch 620
# Train set - loss: 0.002, accuracy: 1.0
# Test  set - loss: 0.681, accuracy: 0.976
#
# epoch 630
# Train set - loss: 0.002, accuracy: 1.0
# Test  set - loss: 0.911, accuracy: 0.976
#
# epoch 640
# Train set - loss: 0.002, accuracy: 1.0
# Test  set - loss: 0.771, accuracy: 0.975
#
# epoch 650
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 0.806, accuracy: 0.976
#
# epoch 660
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 0.908, accuracy: 0.975
#
# epoch 670
# Train set - loss: 0.002, accuracy: 1.0
# Test  set - loss: 0.868, accuracy: 0.975
#
# epoch 680
# Train set - loss: 0.002, accuracy: 1.0
# Test  set - loss: 0.884, accuracy: 0.976
#
# epoch 690
# Train set - loss: 0.002, accuracy: 1.0
# Test  set - loss: 0.955, accuracy: 0.976
#
# epoch 700
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 0.884, accuracy: 0.977
#
# epoch 710
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 0.899, accuracy: 0.976
#
# epoch 720
# Train set - loss: 0.002, accuracy: 1.0
# Test  set - loss: 0.717, accuracy: 0.975
#
# epoch 730
# Train set - loss: 0.959, accuracy: 0.957
# Test  set - loss: 1.314, accuracy: 0.948
#
# epoch 740
# Train set - loss: 0.134, accuracy: 0.976
# Test  set - loss: 0.153, accuracy: 0.963
#
# epoch 750
# Train set - loss: 0.076, accuracy: 0.976
# Test  set - loss: 0.115, accuracy: 0.968
#
# epoch 760
# Train set - loss: 0.041, accuracy: 0.988
# Test  set - loss: 0.121, accuracy: 0.971
#
# epoch 770
# Train set - loss: 0.022, accuracy: 0.994
# Test  set - loss: 0.113, accuracy: 0.977
#
# epoch 780
# Train set - loss: 0.009, accuracy: 0.998
# Test  set - loss: 0.174, accuracy: 0.978
#
# epoch 790
# Train set - loss: 0.004, accuracy: 0.999
# Test  set - loss: 0.371, accuracy: 0.976
#
# epoch 800
# Train set - loss: 0.003, accuracy: 1.0
# Test  set - loss: 0.535, accuracy: 0.979
#
# epoch 810
# Train set - loss: 0.002, accuracy: 1.0
# Test  set - loss: 0.582, accuracy: 0.979
#
# epoch 820
# Train set - loss: 0.002, accuracy: 1.0
# Test  set - loss: 0.672, accuracy: 0.979
#
# epoch 830
# Train set - loss: 0.002, accuracy: 1.0
# Test  set - loss: 0.654, accuracy: 0.978
#
# epoch 840
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 0.658, accuracy: 0.978
#
# epoch 850
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 0.759, accuracy: 0.978
#
# epoch 860
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 0.825, accuracy: 0.977
#
# epoch 870
# Train set - loss: 0.002, accuracy: 1.0
# Test  set - loss: 0.792, accuracy: 0.978
#
# epoch 880
# Train set - loss: 0.002, accuracy: 1.0
# Test  set - loss: 0.812, accuracy: 0.978
#
# epoch 890
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 0.677, accuracy: 0.979
#
# epoch 900
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 0.823, accuracy: 0.978
#
# epoch 910
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 0.771, accuracy: 0.979
#
# epoch 920
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 0.774, accuracy: 0.978
#
# epoch 930
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 0.835, accuracy: 0.978
#
# epoch 940
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 0.873, accuracy: 0.978
#
# epoch 950
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 0.875, accuracy: 0.978
#
# epoch 960
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 0.78, accuracy: 0.979
#
# epoch 970
# Train set - loss: 0.002, accuracy: 1.0
# Test  set - loss: 0.8, accuracy: 0.979
#
# epoch 980
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 0.816, accuracy: 0.979
#
# epoch 990
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 0.733, accuracy: 0.977
#
# epoch 1000
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 0.809, accuracy: 0.978
#
# epoch 1010
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 0.885, accuracy: 0.979
#
# epoch 1020
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.008, accuracy: 0.979
#
# epoch 1030
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 0.945, accuracy: 0.977
#
# epoch 1040
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 0.985, accuracy: 0.979
#
# epoch 1050
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 0.907, accuracy: 0.978
#
# epoch 1060
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 0.936, accuracy: 0.979
#
# epoch 1070
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 0.878, accuracy: 0.979
#
# epoch 1080
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 0.972, accuracy: 0.979
#
# epoch 1090
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.018, accuracy: 0.977
#
# epoch 1100
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.059, accuracy: 0.977
#
# epoch 1110
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 0.994, accuracy: 0.978
#
# epoch 1120
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.093, accuracy: 0.977
#
# epoch 1130
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.014, accuracy: 0.978
#
# epoch 1140
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.086, accuracy: 0.978
#
# epoch 1150
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.125, accuracy: 0.978
#
# epoch 1160
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.093, accuracy: 0.977
#
# epoch 1170
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.101, accuracy: 0.978
#
# epoch 1180
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.035, accuracy: 0.978
#
# epoch 1190
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.08, accuracy: 0.978
#
# epoch 1200
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.129, accuracy: 0.978
#
# epoch 1210
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.105, accuracy: 0.979
#
# epoch 1220
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.027, accuracy: 0.978
#
# epoch 1230
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 0.994, accuracy: 0.978
#
# epoch 1240
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.083, accuracy: 0.978
#
# epoch 1250
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.153, accuracy: 0.978
#
# epoch 1260
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.124, accuracy: 0.977
#
# epoch 1270
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.101, accuracy: 0.976
#
# epoch 1280
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.107, accuracy: 0.977
#
# epoch 1290
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 0.995, accuracy: 0.976
#
# epoch 1300
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.059, accuracy: 0.978
#
# epoch 1310
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.019, accuracy: 0.979
#
# epoch 1320
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 0.942, accuracy: 0.978
#
# epoch 1330
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 0.942, accuracy: 0.979
#
# epoch 1340
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.018, accuracy: 0.978
#
# epoch 1350
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 0.95, accuracy: 0.978
#
# epoch 1360
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.088, accuracy: 0.978
#
# epoch 1370
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.024, accuracy: 0.978
#
# epoch 1380
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.079, accuracy: 0.978
#
# epoch 1390
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.029, accuracy: 0.977
#
# epoch 1400
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.106, accuracy: 0.977
#
# epoch 1410
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.067, accuracy: 0.978
#
# epoch 1420
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.1, accuracy: 0.977
#
# epoch 1430
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.017, accuracy: 0.978
#
# epoch 1440
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.135, accuracy: 0.978
#
# epoch 1450
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.047, accuracy: 0.978
#
# epoch 1460
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.159, accuracy: 0.978
#
# epoch 1470
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.068, accuracy: 0.978
#
# epoch 1480
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.138, accuracy: 0.978
#
# epoch 1490
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.122, accuracy: 0.978
#
# epoch 1500
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.109, accuracy: 0.978
#
# epoch 1510
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.027, accuracy: 0.977
#
# epoch 1520
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.126, accuracy: 0.978
#
# epoch 1530
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.143, accuracy: 0.978
#
# epoch 1540
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.027, accuracy: 0.978
#
# epoch 1550
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.108, accuracy: 0.978
#
# epoch 1560
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.132, accuracy: 0.978
#
# epoch 1570
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.125, accuracy: 0.978
#
# epoch 1580
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.183, accuracy: 0.978
#
# epoch 1590
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.218, accuracy: 0.977
#
# epoch 1600
# Train set - loss: 0.0, accuracy: 1.0
# Test  set - loss: 1.201, accuracy: 0.978
#
# epoch 1610
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.21, accuracy: 0.978
#
# epoch 1620
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.273, accuracy: 0.977
#
# epoch 1630
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.18, accuracy: 0.977
#
# epoch 1640
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.18, accuracy: 0.978
#
# epoch 1650
# Train set - loss: 0.0, accuracy: 1.0
# Test  set - loss: 1.152, accuracy: 0.977
#
# epoch 1660
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.164, accuracy: 0.977
#
# epoch 1670
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.114, accuracy: 0.978
#
# epoch 1680
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.179, accuracy: 0.978
#
# epoch 1690
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.213, accuracy: 0.977
#
# epoch 1700
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.239, accuracy: 0.977
#
# epoch 1710
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.161, accuracy: 0.977
#
# epoch 1720
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.231, accuracy: 0.977
#
# epoch 1730
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.285, accuracy: 0.977
#
# epoch 1740
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.27, accuracy: 0.977
#
# epoch 1750
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.287, accuracy: 0.978
#
# epoch 1760
# Train set - loss: 0.002, accuracy: 1.0
# Test  set - loss: 1.36, accuracy: 0.976
#
# epoch 1770
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.244, accuracy: 0.978
#
# epoch 1780
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.14, accuracy: 0.977
#
# epoch 1790
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.208, accuracy: 0.976
#
# epoch 1800
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.132, accuracy: 0.977
#
# epoch 1810
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.054, accuracy: 0.979
#
# epoch 1820
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.126, accuracy: 0.978
#
# epoch 1830
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.077, accuracy: 0.979
#
# epoch 1840
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.207, accuracy: 0.978
#
# epoch 1850
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.13, accuracy: 0.979
#
# epoch 1860
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.081, accuracy: 0.979
#
# epoch 1870
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.202, accuracy: 0.979
#
# epoch 1880
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.259, accuracy: 0.978
#
# epoch 1890
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.153, accuracy: 0.977
#
# epoch 1900
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.15, accuracy: 0.978
#
# epoch 1910
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.138, accuracy: 0.979
#
# epoch 1920
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.243, accuracy: 0.976
#
# epoch 1930
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.187, accuracy: 0.977
#
# epoch 1940
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.246, accuracy: 0.977
#
# epoch 1950
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.129, accuracy: 0.977
#
# epoch 1960
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.115, accuracy: 0.978
#
# epoch 1970
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.032, accuracy: 0.979
#
# epoch 1980
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.065, accuracy: 0.979
#
# epoch 1990
# Train set - loss: 0.001, accuracy: 1.0
# Test  set - loss: 1.085, accuracy: 0.978

# %%
plt.plot(Results.Epoch,Results.Acc_train,'r',Results.Epoch,Results.Acc_test,'b')
plt.legend(['Train','Test'])
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.show()
print(Results)
# Out:
#       Epoch  Acc_train  Acc_test  test_loss  train_loss
# 0       0.0      0.278     0.280      0.716       0.716
# 1      10.0      0.785     0.791      0.360       0.372
# 2      20.0      0.906     0.906      0.268       0.274
# 3      30.0      0.938     0.930      0.235       0.223
# 4      40.0      0.956     0.949      0.187       0.148
# ..      ...        ...       ...        ...         ...
# 195  1950.0      1.000     0.977      1.129       0.001
# 196  1960.0      1.000     0.978      1.115       0.001
# 197  1970.0      1.000     0.979      1.032       0.001
# 198  1980.0      1.000     0.979      1.065       0.001
# 199  1990.0      1.000     0.978      1.085       0.001
#
# [200 rows x 5 columns]

# %%
plt.plot(Results.Epoch,Results.train_loss,'r',Results.Epoch,Results.test_loss,'b')
plt.legend(['Train','Test'])
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# %%
classes = ['No Voice', 'Voice']
y_pred = CNN(X_test)
y_pred = y_pred.ge(.5).view(-1).cpu()
y_test = y_test.cpu()
print(classification_report(y_test, y_pred, target_names=classes))
# Out:
#               precision    recall  f1-score   support
#
#     No Voice       0.98      0.99      0.99      4021
#        Voice       0.96      0.95      0.96      1254
#
#     accuracy                           0.98      5275
#    macro avg       0.97      0.97      0.97      5275
# weighted avg       0.98      0.98      0.98      5275

# %%
cm = confusion_matrix(y_test, y_pred)
df_cm = pd.DataFrame(cm, index=classes, columns=classes)
hmap = sns.heatmap(df_cm, annot=True, fmt="d", cmap= 'crest')
#hmap.color_palette("viridis", as_cmap=True)
hmap.yaxis.set_ticklabels(hmap.yaxis.get_ticklabels(), rotation=0, ha='right')
hmap.xaxis.set_ticklabels(hmap.xaxis.get_ticklabels(), rotation=30, ha='right')
plt.ylabel('True label')
plt.xlabel('Predicted label');

# %%
y_pred = CNN(X_val)
y_pred = y_pred.ge(.5).view(-1).cpu()
y_val = y_val.cpu()
print(classification_report(y_val, y_pred, target_names=classes))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_24726/1053045193.py in <module>
# ----> 1 y_pred = CNN(X_val)
#       2 y_pred = y_pred.ge(.5).view(-1).cpu()
#       3 y_val = y_val.cpu()
#       4 print(classification_report(y_val, y_pred, target_names=classes))
#
# /opt/jupyterhub/anaconda/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# /tmp/ipykernel_24726/91884544.py in forward(self, x)
#      16
#      17     def forward(self, x):
# ---> 18         x = F.relu(F.max_pool1d(self.conv1(x), 1))
#      19         x = F.relu(F.max_pool1d(self.conv2(x), 1))
#      20         x = F.relu(F.max_pool1d(self.conv3(x), 1))
#
# /opt/jupyterhub/anaconda/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# /opt/jupyterhub/anaconda/lib/python3.9/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     299
#     300     def forward(self, input: Tensor) -> Tensor:
# --> 301         return self._conv_forward(input, self.weight, self.bias)
#     302
#     303
#
# /opt/jupyterhub/anaconda/lib/python3.9/site-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight, bias)
#     295                             weight, bias, self.stride,
#     296                             _single(0), self.dilation, self.groups)
# --> 297         return F.conv1d(input, weight, bias, self.stride,
#     298                         self.padding, self.dilation, self.groups)
#     299
#
# RuntimeError: Given groups=1, weight of size [1280, 640, 1], expected input[1, 1760, 2300] to have 640 channels, but got 1760 channels instead

# %%
cm = confusion_matrix(y_val, y_pred)
df_cm = pd.DataFrame(cm, index=classes, columns=classes)
hmap = sns.heatmap(df_cm, annot=True, fmt="d", cmap= 'crest')
hmap.yaxis.set_ticklabels(hmap.yaxis.get_ticklabels(), rotation=0, ha='right')
hmap.xaxis.set_ticklabels(hmap.xaxis.get_ticklabels(), rotation=30, ha='right')
plt.ylabel('True label')
plt.xlabel('Predicted label');

# %%
#Shutting down the notebook

# %%javascript
Jupyter.notebook.session.delete();
# Out:
# UsageError: Line magic function `%%javascript` not found.
