# %%
import numpy as np
import pandas as pd
import os

os.listdir("dialogue/Amber")
# Out:
# ['voice-dataframe-function.ipynb',
#  'dataset-df-function.ipynb',
#  'south-park-Copy1.ipynb',
#  'Update-voice-and-background-audio-dataset',
#  'S04.json',
#  'dataset-voice-df.ipynb',
#  '.ipynb_checkpoints',
#  'All-seasons-Copy1.csv',
#  'dataset-dataframe.ipynb']

# %%
df = pd.read_csv("dialogue/Amber/All-seasons-Copy1.csv")
df.head(10)
# Out:
#   Season Episode      Character  \
# 0     10       1           Stan
# 1     10       1           Kyle
# 2     10       1           Stan
# 3     10       1           Chef
# 4     10       1           Stan
# 5     10       1           Chef
# 6     10       1  Mrs. Garrison
# 7     10       1           Chef
# 8     10       1  Mrs. Garrison
# 9     10       1        Cartman
#
#                                                 Line
# 0         You guys, you guys! Chef is going away. \n
# 1                        Going away? For how long?\n
# 2                                         Forever.\n
# 3                                  I'm sorry boys.\n
# 4  Chef said he's been bored, so he joining a gro...
# 5                                             Wow!\n
# 6  Chef?? What kind of questions do you think adv...
# 7     What's the meaning of life? Why are we here?\n
# 8           I hope you're making the right choice.\n
# 9  I'm gonna miss him.  I'm gonna miss Chef and I...
